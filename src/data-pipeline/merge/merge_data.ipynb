# %%
import os
os.chdir("..")  # ← remonte dans data-pipeline/
print(os.getcwd())  # vérification
# Out:
# c:\Users\Utilisateur\Desktop\projects\GeoLogis\data-pipeline

# %%
import pandas as pd

# %%
df = pd.read_csv('raw/communes-france-2025.csv')
df
# Out:
# C:\Users\Utilisateur\AppData\Local\Temp\ipykernel_17420\1818052200.py:1: DtypeWarning: Columns (1,12,14,16,23,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('raw/communes-france-2025.csv')
#        Unnamed: 0 code_insee             nom_standard        nom_sans_pronom  \
# 0               0      01001  L'Abergement-Clémenciat  Abergement-Clémenciat
# 1               1      01002    L'Abergement-de-Varey    Abergement-de-Varey
# 2               2      01004        Ambérieu-en-Bugey      Ambérieu-en-Bugey
# 3               3      01005      Ambérieux-en-Dombes    Ambérieux-en-Dombes
# 4               4      01006                  Ambléon                Ambléon
# ...           ...        ...                      ...                    ...
# 34930       34930      97613            M'Tsangamouji          M'Tsangamouji
# 34931       34931      97614                 Ouangani               Ouangani
# ...

# %%
import pandas as pd

df = pd.read_csv('raw/immo_data.csv')
columns = ['adresse_numero', 'adresse_suffixe', 'adresse_nom_voie', 'adresse_code_voie', 'code_postal', 'code_commune', 'nom_commune', 'code_departement', 'ancien_code_commune', 'ancien_nom_commune']

df[columns]
# Out:
# C:\Users\Utilisateur\AppData\Local\Temp\ipykernel_17420\2762195721.py:3: DtypeWarning: Columns (18,19,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('raw/immo_data.csv')
#        adresse_numero adresse_suffixe   adresse_nom_voie adresse_code_voie  \
# 0                 NaN             NaN       SAINT JULIEN              B064
# 1                 NaN             NaN       A LA PEROUSE              B188
# 2                 NaN             NaN       A LA PEROUSE              B188
# 3                 NaN             NaN        AUX COMMUNS              B079
# 4                 NaN             NaN      EN COMBARNAUD              B033
# ...               ...             ...                ...               ...
# 49995           121.0             NaN        CHE DU LERY              0092
# 49996             NaN             NaN        CHE DU LERY              0092
# 49997             4.0             NaN  ALL MAURICE RAVEL              1003
# ...
